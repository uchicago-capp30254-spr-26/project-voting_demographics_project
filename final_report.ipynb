# %% [markdown]
# ## <div align="center"> Final Report: Voting Demographics </div>
# <div align="right"> Team Members: Ashanti Hatchett, Srinath Pathangae, Kumhyun Song </div>

# %% [markdown]
# ### Introduction
# What policy problem were you trying to explore? Why is this problem important? What policy implications could your work have?
#
# This project explores how the demographics of registered voters affect their participation in elections, using voter turnout data from the 2024 U.S. presidential election. The policy problem we address is persistently unequal voter participation across demographic groups, which can undermine democratic representation.
#
# Understanding which demographic groups are more or less likely to vote is important for policymakers and election officials seeking to increase overall voter turnout. If certain groups consistently participate at lower rates, their preferences may be underrepresented in electoral outcomes.
#
# Using the results of our analysis, we aim to predict whether an individual voter is likely to turn out. Such predictions could help inform targeted outreach strategies designed to encourage participation among voters who are less likely to vote. In this context, identifying individuals who ultimately do not vote is particularly important, as policy interventions would be directed toward these groups.
#
# In a democratic society, voter turnout is a critical indicator of political participation, as higher turnout allows a broader range of citizens’ voices to be reflected in electoral outcomes.
#
# To make these predictions, we employ three models: logistic regression, random forests, and neural networks. We evaluate their performance using the F1 score, which is appropriate for our analysis because the dataset is imbalanced, as will be discussed in the Data section.

# %% [markdown]
# ### Data
# What data did you use (including features and your extracted feature)? What did you have to do to clean and prepare your dataset? What were the limitations of the data? What features do you wish your data had?

# %% [markdown]
# ### Model 1: Logistic Regression
# How did you pick your models and tune them? What was the best-performing model out of all you tried, given the metrics you used? What was the worst-performing model? Any ideas why?

# %% [markdown]
# ### Model 2: Random Forests
# How did you pick your models and tune them? What was the best-performing model out of all you tried, given the metrics you used? What was the worst-performing model? Any ideas why?

# %% [markdown]
# ### Model 3: Neural Networks
# How did you pick your models and tune them? What was the best-performing model out of all you tried, given the metrics you used? What was the worst-performing model? Any ideas why?

# %% [markdown]
# ### Surprises
# Did anything unexpected happen? What parts of the project were surprisingly difficult?

# %% [markdown]
# ### Conclusion
# What did you learn about your research question? What did you learn about machine learning through the tasks?  How would you continue this research if you wanted to further investigate? If you had more time and infinite resources, how would you continue your project?
